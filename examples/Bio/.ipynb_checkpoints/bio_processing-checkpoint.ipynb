# %% [markdown]
# # Biosignals Processing in Python

# %%
# Import packages
import neurokit as nk
import pandas as pd
import numpy as np
import matplotlib

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = [12.0, 8.0]  # Bigger figures

# %% [markdown]
# ## Import Data

# %%
df = pd.read_csv("data_bio.csv")
df.plot()

# %% [markdown]
# df contains 3.5 minutes of data recorded at 1000Hz. There are 4 channels, EDA, ECG, RSP and the Photosensor used to localize events.

# %% [markdown]
# ## Process it

# %%
bio_features = nk.process_bio(ecg=df["ECG"], rsp=df["RSP"], eda=df["EDA"])
bio_features.keys()  # See what it contains
# Out:
# dict_keys(['EDA_Raw', 'RSP_Rate', 'Heart_Rate', 'Heart_Beats', 'EDA_Filtered', 'SCR_Onsets', 'RSP_Raw', 'SCR_Peaks_Amplitudes', 'RSP_Filtered', 'ECG_Filtered', 'ECG_Rpeaks_Indexes', 'HRV', 'EDA_Phasic', 'ECG_Raw', 'SCR_Peaks_Indexes'])

# %% [markdown]
# ## ECG Miscellaenous

# %% [markdown]
# ### Heart Beats

# %%
pd.DataFrame(bio_features["Heart_Beats"]).T.plot(legend=False)  # Plot all the heart beats

# %% [markdown]
# This plot contains all 274 detected heart beats synchronized by their R peak.

# %% [markdown]
# ### Heart Rate Variability (HRV)

# %%
# Print all the HRV indices
print(bio_features["HRV"])
# Out:
# {'pnn50': 4.7800000000000002, 'vlf': 363.76999999999998, 'nn50': 13.0, 'lf_hf': 7.1500000000000004, 'lfnu': 87.730000000000004, 'total_power': 2280.6799999999998, 'sdnn': 50.920000000000002, 'hfnu': 12.27, 'mhr': 78.969999999999999, 'hf': 235.12, 'lf': 1681.79, 'rmssd': 24.699999999999999, 'mrri': 763.14999999999998}

# %% [markdown]
# ## Add Processed Signals  to Data Frame

# %%
df["ECG_Filtered"] = bio_features["ECG_Filtered"]
df["Heart_Rate"] = bio_features["Heart_Rate"]
df["RSP_Filtered"] = bio_features["RSP_Filtered"]
df["RSP_Rate"] = bio_features["RSP_Rate"]
df["EDA_Phasic"] = bio_features["EDA_Phasic"]

# %%
df[["Heart_Rate", "RSP_Rate", "EDA_Phasic", "Photosensor"]].plot()

# %% [markdown]
# ## Event-Related Analysis

# %% [markdown]
# This experiment consisted of 8 events (when the photosensor signal goes down). 2 types of images were shown to the participant, "Negative" vs "Neutral". The following list is the order.

# %%
condition_list = ["Negative", "Neutral", "Neutral", "Neutral", "Negative", "Neutral", "Negative", "Negative"]

# %% [markdown]
# ### Locate Events

# %% [markdown]
# First, we must find events onset within our photosensor's signal using the `find_events()` function. This functions requires a treshold and a direction (should it select events that are *higher* or *lower* than the treshold).

# %%
events_onsets = nk.find_events(df["Photosensor"], treshold = 3, cut="lower")
