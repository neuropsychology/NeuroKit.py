# %% [markdown]
# # Biosignals Preprocessing

# %%
import neurokit as nk
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv("data_bio.csv")

# %%
df.plot()

# %%
bio_features = nk.process_bio(ecg=df["ECG"], rsp=df["RSP"], eda=df["EDA"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-fb07916cc9af> in <module>()
# ----> 1 bio_features = nk.process_bio(ecg=df["ECG"], rsp=df["RSP"], eda=df["EDA"])
#
# C:\Users\Dom\Desktop\WinPython-32bit-3.5.3.0Qt5\python-3.5.3\lib\site-packages\neurokit\bio\bio_meta.py in process_bio(ecg, rsp, eda, sampling_rate, resampling_method, cvxEDA)
#      63
#      64     if eda is not None:
# ---> 65         bio_features.update(process_eda(eda=eda, sampling_rate=sampling_rate, cvxEDA=cvxEDA))
#      66
#      67     return(bio_features)
#
# C:\Users\Dom\Desktop\WinPython-32bit-3.5.3.0Qt5\python-3.5.3\lib\site-packages\neurokit\bio\bio_eda.py in process_eda(eda, sampling_rate, cvxEDA)
#      66     # Convex optimization
#      67     if cvxEDA is True:
# ---> 68         eda = cvxEDA(eda, sampling_rate=sampling_rate)
#      69         eda_features["EDA_Phasic"] = eda
#      70
#
# TypeError: 'bool' object is not callable
